# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('data.csv')
data
# Out:
#          AT      V       AP     RH      PE
# 0      8.34  40.77  1010.84  90.01  480.48
# 1     23.64  58.49  1011.40  74.20  445.75
# 2     29.74  56.90  1007.15  41.91  438.76
# 3     19.07  49.69  1007.22  76.79  453.09
# 4     11.80  40.66  1017.13  97.20  464.43
# ...     ...    ...      ...    ...     ...
# 9563  15.12  48.92  1011.80  72.93  462.59
# 9564  33.41  77.95  1010.30  59.72  432.90
# 9565  15.99  43.34  1014.20  78.66  465.96
# 9566  17.65  59.87  1018.58  94.65  450.93
# 9567  23.68  51.30  1011.86  71.24  451.67
#
# [9568 rows x 5 columns]

# %%
data.head()
# Out:
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 4  11.80  40.66  1017.13  97.20  464.43

# %%
x=data.drop(['PE'], axis=1).values
y=data['PE'].values
print(y)
# Out:
# [480.48 445.75 438.76 ... 465.96 450.93 451.67]

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.2, random_state=0)

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pre = reg.predict(x_test)
y_pre
# Out:
# array([433.36241603, 448.38864548, 445.88661799, ..., 456.06061126,
#        446.91190634, 432.57326179])

# %%
r2_score(y_test, y_pre)
# Out:
# 0.9298994694436788

# %%
plt.figure(figsize=(15,10))
plt.scatter(y_test, y_pre)
plt.xlabel('Actual')
plt.ylabel('Prediction')
plt.title('Actual vs Prediction')
# Out:
# Text(0.5, 1.0, 'Actual vs Prediction')

# %%
pred_y=pd.DataFrame({'Actual value' : y_test, 'Predicted values':y_pre, 'Difference': y_test-y_pre})
pred_y[0:20]
# Out:
#     Actual value  Predicted values  Difference
# 0         426.18        433.362416   -7.182416
# 1         451.10        448.388645    2.711355
# 2         442.87        445.886618   -3.016618
# 3         443.70        445.991729   -2.291729
# 4         460.59        462.811283   -2.221283
# 5         438.00        440.848694   -2.848694
# 6         484.31        482.724175    1.585825
# 7         464.18        462.228915    1.951085
# 8         452.53        451.252188    1.277812
# 9         445.54        445.418624    0.121376
# 10        435.14        441.188685   -6.048685
# 11        442.03        442.211770   -0.181770
# 12        454.02        456.294962   -2.274962
# 13        445.02        449.505187   -4.485187
# 14        446.53        449.510412   -2.980412
# 15        458.59        457.164048    1.425952
# 16        445.84        450.576101   -4.736101
# 17        471.46        468.880957    2.579043
# 18        452.84        454.555432   -1.715432
# 19        448.64        452.398290   -3.758290
